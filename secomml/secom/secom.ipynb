# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("secom.data", delim_whitespace=True, header=None)
labels = pd.read_csv("secom_labels.data", delim_whitespace=True, header=None)
df['Target'] = labels[0]
df.head()
# Out:
# C:\Users\adarsh kumar\AppData\Local\Temp\ipykernel_2444\609052246.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("secom.data", delim_whitespace=True, header=None)
# C:\Users\adarsh kumar\AppData\Local\Temp\ipykernel_2444\609052246.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   labels = pd.read_csv("secom_labels.data", delim_whitespace=True, header=None)
#          0        1          2          3       4      5         6       7  \
# 0  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# ...

# %%
df.head(5)
# Out:
#          0        1          2          3       4      5         6       7  \
# 0  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
#
#         8       9  ...       581     582     583     584      585     586  \
# 0  1.5005  0.0162  ...       NaN  0.5005  0.0118  0.0035   2.3630     NaN
# 1  1.4966 -0.0005  ...  208.2045  0.5019  0.0223  0.0055   4.4447  0.0096
# 2  1.4436  0.0041  ...   82.8602  0.4958  0.0157  0.0039   3.1745  0.0584
# 3  1.4882 -0.0124  ...   73.8432  0.4990  0.0103  0.0025   2.0544  0.0202
# 4  1.5031 -0.0031  ...       NaN  0.4800  0.4766  0.1045  99.3032  0.0202
#
#       587     588       589  Target
# ...

# %%
df.isnull().sum()
# Out:
# 0          6
# 1          7
# 2         14
# 3         14
# 4         14
#           ..
# 586        1
# 587        1
# 588        1
# 589        1
# Target     0
# Length: 591, dtype: int64

# %%
df.fillna(df.mean(axis=1),inplace=True)

# %%
df.shape
df.dtypes
# Out:
# 0         float64
# 1         float64
# 2         float64
# 3         float64
# 4         float64
#            ...
# 586       float64
# 587       float64
# 588       float64
# 589       float64
# Target      int64
# Length: 591, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Columns: 591 entries, 0 to Target
# dtypes: float64(590), int64(1)
# memory usage: 7.1 MB

# %%
df.describe()
# Out:
#                  0            1            2            3            4  \
# count  1567.000000  1567.000000  1567.000000  1567.000000  1567.000000
# mean   3003.187165  2485.010437  2181.474278  1384.540194     4.816862
# std     196.061159   180.663189   203.082979   457.054194    56.481868
# min      72.219533    69.284887    65.729251     0.000000     0.681500
# 25%    2965.670000  2451.515000  2180.700000  1080.116050     1.017700
# 50%    3010.920000  2498.910000  2200.955600  1283.436800     1.317100
# 75%    3056.540000  2538.745000  2218.055500  1590.169900     1.529600
# max    3356.350000  2846.440000  2315.266700  3715.041700  1114.536600
#
#                  5            6            7            8            9  ...  \
# count  1567.000000  1567.000000  1567.000000  1567.000000  1567.000000  ...
# mean     99.745281   100.857778     0.492241     1.589991     0.088873  ...
# std       2.683620     6.766105     4.875241     3.558114     2.510435  ...
# ...

# %%
X=df.drop('Target',axis=1)
y=df['Target']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
from sklearn.decomposition import PCA

pca = PCA().fit(X_scaled)
plt.figure(figsize=(8,5))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance vs Components')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split,cross_val_score
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
Xts=scaler.fit_transform(X_train)
Xtests=scaler.transform(X_test)

# %%
pcA=PCA(n_components=100)
Xtspca=pcA.fit_transform(Xts)

Xtestpca=pcA.fit_transform(Xtests)

# %% [markdown]
# PCA IS DONE

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
models ={"Logistic Regression" : LogisticRegression(max_iter=1000,class_weight='balanced'),
       "Random Forest Classifier":RandomForestClassifier(class_weight='balanced',random_state=42)
       ,"SVM":SVC(class_weight='balanced')}
for i ,j in models.items():
    scores=cross_val_score(j,Xtspca,y_train,cv=5,scoring='f1')
    print(scores)
    print(i,np.mean(scores))
# Out:
# [0.14705882 0.10958904 0.19047619 0.1875     0.05405405]
# Logistic Regression 0.13773562183110935
# [0. 0. 0. 0. 0.]
# Random Forest Classifier 0.0
# [0.19672131 0.07272727 0.19672131 0.16326531 0.13043478]
# SVM 0.1519739968818474

# %%
y.value_counts(normalize=True)
##it signifies data is too imbalance
# Out:
# Target
# -1    0.933631
#  1    0.066369
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=42)
Xr_train,yr_train=sm.fit_resample(Xtspca,y_train)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf']
}
grid = GridSearchCV(SVC(class_weight='balanced'), param_grid, cv=5, scoring='f1')
grid.fit(Xr_train, yr_train)
print(grid.best_params_, grid.best_score_)
# Out:
# {'C': 10, 'kernel': 'rbf'} 0.9855443170871622
